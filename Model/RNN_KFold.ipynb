# %%
import pandas as pd

# %%
# data = pd.read_csv('../data_mfccRMScqt.csv')
data = pd.read_csv('../Preprocessing/db1/data_MfccDwtRmsCqtdb1L5.csv')
data.head()
# Out:
#                               filename       mfcc1      mfcc2      mfcc3  \
# 0  ../data/DWT_NEW/MVP/New_MVP_062.wav   88.547943 -34.731178  17.439774
# 1  ../data/DWT_NEW/MVP/New_MVP_109.wav  130.248093 -18.175362  -7.527256
# 2  ../data/DWT_NEW/MVP/New_MVP_009.wav   68.611404 -30.707958  43.091286
# 3  ../data/DWT_NEW/MVP/New_MVP_177.wav  124.010841 -26.582684   4.632347
# 4  ../data/DWT_NEW/MVP/New_MVP_069.wav   87.647217 -33.906952   0.952698
#
#        mfcc4      mfcc5      mfcc6      mfcc7      mfcc8     mfcc9  ...  \
# 0   3.966827 -17.346939  18.881588 -17.580509   8.225138  2.163004  ...
# 1  -1.821126  -0.783999   9.139212 -30.255112 -18.019503 -3.269579  ...
# 2  -5.395578 -31.639091  25.854515 -19.372128  12.241970 -3.681171  ...
# 3  -2.877658  -2.610994   1.804899  -2.408908   5.523919 -0.094534  ...
# 4 -12.743137 -30.600828  29.831501 -26.453606   7.694873  0.659293  ...
#
#       cqt52     cqt53     cqt54     cqt55     cqt56     cqt57     cqt58  \
# 0  0.162481  0.128590  0.253865  0.286246  0.232347  0.166034  0.149659
# 1  0.272742  0.214996  0.163759  0.185034  0.284470  0.427768  0.583855
# 2  0.268128  0.329467  0.240955  0.215759  0.290983  0.327005  0.241768
# 3  0.535192  0.555842  0.328036  0.101016  0.362609  0.401901  0.259996
# 4  0.448852  0.387767  0.466638  0.528683  0.326940  0.347330  0.452033
#
#       cqt59     cqt60  label
# 0  0.175466  0.264108    MVP
# 1  0.714654  0.804361    MVP
# 2  0.163038  0.190981    MVP
# 3  0.146674  0.301535    MVP
# 4  0.500666  0.408247    MVP
#
# [5 rows x 103 columns]

# %%
import numpy as np
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras import models, layers
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

lb = LabelEncoder()
X = data.drop(['label', 'filename'], axis=1)
y = data.iloc[:, -1]

skf = StratifiedKFold(n_splits=5, random_state=None, shuffle=False)

def build_model():
        model = models.Sequential(
            [
            layers.SimpleRNN(64,activation='tanh',input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True),
            layers.Dense(32, activation="relu"),

            layers.Flatten(),
            layers.Dense(64, activation="relu"),
            layers.Dense(32, activation="relu"),

            layers.Dense(5, activation="softmax"),
            # layers.SimpleRNN(64,activation='tanh',input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True),
            # layers.Dense(32, activation="relu", activity_regularizer=tf.keras.regularizers.l2(1e-4)),

            # layers.Flatten(),
            # layers.Dense(64, activation="relu", activity_regularizer=tf.keras.regularizers.l2(1e-4)),
            # layers.Dense(32, activation="relu", activity_regularizer=tf.keras.regularizers.l2(1e-4)),
            

            # layers.Dense(5, activation="softmax"),
            ]
        )

        return model
no = 1
for train_index, test_index in skf.split(X, y):
    # print("TRAIN:", train_index, "TEST:", test_index)
    print("Fold: ", no)
    print("TRAIN:", len(train_index), "TEST:", len(test_index))
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]

    X_train = np.expand_dims(X_train, axis=2)
    X_test = np.expand_dims(X_test, axis=2)
    y_test = tf.keras.utils.to_categorical(lb.fit_transform(y_test))
    y_train = tf.keras.utils.to_categorical(lb.fit_transform(y_train))

    model = build_model()
    optimazer = tf.keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimazer, loss='categorical_crossentropy', metrics=['acc'])
    history = model.fit(X_train, y_train, epochs=50, batch_size=64, validation_data=(X_test, y_test), verbose=0)
    # history = model.fit(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_test, y_test), verbose=0)

    y_pred = model.predict(X_test)
    y_pred = np.argmax(y_pred, axis=1)
    y_test = np.argmax(y_test, axis=1)

    print('Accuracy: ', accuracy_score(y_test, y_pred))
    print('Precision: ', precision_score(y_test, y_pred, average='macro'))
    print('Recall: ', recall_score(y_test, y_pred, average='macro'))
    print('F1: ', f1_score(y_test, y_pred, average='macro'))
    
    # y_p = np.argmax(y_pred, axis=1)
    # y_t = np.argmax(y_test, axis=1)
    cm = confusion_matrix(y_test, y_pred)
    cm

    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['AS', 'MR', 'MS', 'MVP', 'N'])
    disp.plot()
    plt.show()

    FP = cm.sum(axis=0) - np.diag(cm)  
    FN = cm.sum(axis=1) - np.diag(cm)
    TP = np.diag(cm)
    TN = cm.sum() - (FP + FN + TP)

    # Sensitivity, hit rate, recall, or true positive rate
    TPR = TP/(TP+FN)
    # Specificity or true negative rate
    TNR = TN/(TN+FP) 
    # Precision or positive predictive value
    PPV = TP/(TP+FP)
    # Negative predictive value
    NPV = TN/(TN+FN)
    # Fall out or false positive rate
    FPR = FP/(FP+TN)
    # False negative rate
    FNR = FN/(TP+FN)
    # False discovery rate
    FDR = FP/(TP+FP)

    # Overall accuracy
    ACC = (TP+TN)/(TP+FP+FN+TN)

    print("TNR : ", TNR)
    print("TPR : ", TPR)
    print("FPR : ", FPR)
    print("FNR : ", FNR)
    print("ACC : ", ACC)
    print("PPV : ", PPV)
    print("NPV : ", NPV)

        
    no += 1
# Out:
# 2023-10-12 11:25:28.006213: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-10-12 11:25:28.042636: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-12 11:25:28.042667: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-12 11:25:28.042690: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-12 11:25:28.048891: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-10-12 11:25:28.049538: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-12 11:25:29.104080: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Fold:  1
# TRAIN: 720 TEST: 180
# 6/6 [==============================] - 0s 5ms/step
# Accuracy:  0.85
# Precision:  0.8553007518796992
# Recall:  0.85
# F1:  0.8513551226192397
# TNR :  [0.96527778 0.95138889 0.9375     0.95833333 1.        ]
# TPR :  [0.83333333 0.86111111 0.86111111 0.80555556 0.88888889]
# FPR :  [0.03472222 0.04861111 0.0625     0.04166667 0.        ]
# FNR :  [0.16666667 0.13888889 0.13888889 0.19444444 0.11111111]
# ACC :  [0.93888889 0.93333333 0.92222222 0.92777778 0.97777778]
# PPV :  [0.85714286 0.81578947 0.775      0.82857143 1.        ]
# NPV :  [0.95862069 0.96478873 0.96428571 0.95172414 0.97297297]
# Fold:  2
# TRAIN: 720 TEST: 180
# 6/6 [==============================] - 0s 5ms/step
# Accuracy:  0.8888888888888888
# Precision:  0.8912877971701502
# Recall:  0.888888888888889
# F1:  0.889649005141963
# TNR :  [0.96527778 0.97222222 0.98611111 0.9375     1.        ]
# TPR :  [0.83333333 0.88888889 0.88888889 0.83333333 1.        ]
# FPR :  [0.03472222 0.02777778 0.01388889 0.0625     0.        ]
# FNR :  [0.16666667 0.11111111 0.11111111 0.16666667 0.        ]
# ACC :  [0.93888889 0.95555556 0.96666667 0.91666667 1.        ]
# PPV :  [0.85714286 0.88888889 0.94117647 0.76923077 1.        ]
# NPV :  [0.95862069 0.97222222 0.97260274 0.95744681 1.        ]
# Fold:  3
# TRAIN: 720 TEST: 180
# 6/6 [==============================] - 0s 5ms/step
# Accuracy:  0.9055555555555556
# Precision:  0.9086527816868374
# Recall:  0.9055555555555556
# F1:  0.9059564420559683
# TNR :  [0.95833333 0.97916667 0.95833333 0.98611111 1.        ]
# TPR :  [0.88888889 0.86111111 0.94444444 0.86111111 0.97222222]
# FPR :  [0.04166667 0.02083333 0.04166667 0.01388889 0.        ]
# FNR :  [0.11111111 0.13888889 0.05555556 0.13888889 0.02777778]
# ACC :  [0.94444444 0.95555556 0.95555556 0.96111111 0.99444444]
# PPV :  [0.84210526 0.91176471 0.85       0.93939394 1.        ]
# NPV :  [0.97183099 0.96575342 0.98571429 0.96598639 0.99310345]
# Fold:  4
# TRAIN: 720 TEST: 180
# 6/6 [==============================] - 0s 5ms/step
# Accuracy:  0.9
# Precision:  0.9024205087440382
# Recall:  0.9
# F1:  0.8999003956304945
# TNR :  [0.96527778 0.98611111 0.95138889 0.97916667 0.99305556]
# TPR :  [0.88888889 0.83333333 0.91666667 0.86111111 1.        ]
# FPR :  [0.03472222 0.01388889 0.04861111 0.02083333 0.00694444]
# FNR :  [0.11111111 0.16666667 0.08333333 0.13888889 0.        ]
# ACC :  [0.95       0.95555556 0.94444444 0.95555556 0.99444444]
# PPV :  [0.86486486 0.9375     0.825      0.91176471 0.97297297]
# NPV :  [0.97202797 0.95945946 0.97857143 0.96575342 1.        ]
# Fold:  5
# TRAIN: 720 TEST: 180
# 6/6 [==============================] - 0s 5ms/step
# Accuracy:  0.9333333333333333
# Precision:  0.9373765494818127
# Recall:  0.9333333333333333
# F1:  0.9331305063587729
# TNR :  [0.95833333 0.98611111 0.97916667 1.         0.99305556]
# TPR :  [0.94444444 0.91666667 0.97222222 0.83333333 1.        ]
# FPR :  [0.04166667 0.01388889 0.02083333 0.         0.00694444]
# FNR :  [0.05555556 0.08333333 0.02777778 0.16666667 0.        ]
# ACC :  [0.95555556 0.97222222 0.97777778 0.96666667 0.99444444]
# PPV :  [0.85       0.94285714 0.92105263 1.         0.97297297]
# NPV :  [0.98571429 0.97931034 0.99295775 0.96       1.        ]

# %%
model = build_model()
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_5 (SimpleRNN)    (None, 101, 64)           4224
#
#  dense_20 (Dense)            (None, 101, 32)           2080
#
#  flatten_5 (Flatten)         (None, 3232)              0
#
#  dense_21 (Dense)            (None, 64)                206912
#
#  dense_22 (Dense)            (None, 32)                2080
#
#  dense_23 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 215461 (841.64 KB)
# Trainable params: 215461 (841.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import numpy as np
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras import models, layers
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

lb = LabelEncoder()
X = data.drop(['label', 'filename'], axis=1)
y = data.iloc[:, -1]

skf = StratifiedKFold(n_splits=5, random_state=None, shuffle=False)

def build_model():
        model = models.Sequential(
            [
                # layers.SimpleRNN(64,activation='tanh',input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True),
                # layers.Dense(32, activation="relu"),

                # layers.Flatten(),
                # layers.Dense(64, activation="relu"),
                # layers.Dense(32, activation="relu"),

                # layers.Dense(5, activation="softmax"),
                layers.SimpleRNN(64,activation='tanh',input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True),
                layers.Dense(32, activation="relu", activity_regularizer=tf.keras.regularizers.l2(1e-4)),

                layers.Flatten(),
                layers.Dense(64, activation="relu", activity_regularizer=tf.keras.regularizers.l2(1e-4)),
                layers.Dense(32, activation="relu", activity_regularizer=tf.keras.regularizers.l2(1e-4)),
                

                layers.Dense(5, activation="softmax"),
            ]
        )

        return model
no = 1
for train_index, test_index in skf.split(X, y):
    # print("TRAIN:", train_index, "TEST:", test_index)
    print("Fold: ", no)
    print("TRAIN:", len(train_index), "TEST:", len(test_index))
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]

    X_train = np.expand_dims(X_train, axis=2)
    X_test = np.expand_dims(X_test, axis=2)
    y_test = tf.keras.utils.to_categorical(lb.fit_transform(y_test))
    y_train = tf.keras.utils.to_categorical(lb.fit_transform(y_train))

    model = build_model()
    optimazer = tf.keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimazer, loss='categorical_crossentropy', metrics=['acc'])
    history = model.fit(X_train, y_train, epochs=50, batch_size=64, validation_data=(X_test, y_test), verbose=0)
    # history = model.fit(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_test, y_test), verbose=0)

    y_pred = model.predict(X_test)
    y_pred = np.argmax(y_pred, axis=1)
    y_test = np.argmax(y_test, axis=1)

    print('Accuracy: ', accuracy_score(y_test, y_pred))
    print('Precision: ', precision_score(y_test, y_pred, average='macro'))
    print('Recall: ', recall_score(y_test, y_pred, average='macro'))
    print('F1: ', f1_score(y_test, y_pred, average='macro'))
    
    # y_p = np.argmax(y_pred, axis=1)
    # y_t = np.argmax(y_test, axis=1)
    cm = confusion_matrix(y_test, y_pred)
    cm

    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['AS', 'MR', 'MS', 'MVP', 'N'])
    disp.plot()
    plt.show()

    FP = cm.sum(axis=0) - np.diag(cm)  
    FN = cm.sum(axis=1) - np.diag(cm)
    TP = np.diag(cm)
    TN = cm.sum() - (FP + FN + TP)

    # Sensitivity, hit rate, recall, or true positive rate
    TPR = TP/(TP+FN)
    # Specificity or true negative rate
    TNR = TN/(TN+FP) 
    # Precision or positive predictive value
    PPV = TP/(TP+FP)
    # Negative predictive value
    NPV = TN/(TN+FN)
    # Fall out or false positive rate
    FPR = FP/(FP+TN)
    # False negative rate
    FNR = FN/(TP+FN)
    # False discovery rate
    FDR = FP/(TP+FP)

    # Overall accuracy
    ACC = (TP+TN)/(TP+FP+FN+TN)

    print("TNR : ", TNR)
    print("TPR : ", TPR)
    print("FPR : ", FPR)
    print("FNR : ", FNR)
    print("ACC : ", ACC)
    print("PPV : ", PPV)
    print("NPV : ", NPV)

        
    no += 1
# Out:
# Fold:  1
# TRAIN: 720 TEST: 180
# 6/6 [==============================] - 0s 5ms/step
# Accuracy:  0.8611111111111112
# Precision:  0.8622918982671305
# Recall:  0.861111111111111
# F1:  0.8613672656697933
# TNR :  [0.95833333 0.97222222 0.95833333 0.95138889 0.98611111]
# TPR :  [0.83333333 0.83333333 0.88888889 0.83333333 0.91666667]
# FPR :  [0.04166667 0.02777778 0.04166667 0.04861111 0.01388889]
# FNR :  [0.16666667 0.16666667 0.11111111 0.16666667 0.08333333]
# ACC :  [0.93333333 0.94444444 0.94444444 0.92777778 0.97222222]
# PPV :  [0.83333333 0.88235294 0.84210526 0.81081081 0.94285714]
# NPV :  [0.95833333 0.95890411 0.97183099 0.95804196 0.97931034]
# Fold:  2
# TRAIN: 720 TEST: 180
# 6/6 [==============================] - 0s 5ms/step
# Accuracy:  0.8777777777777778
# Precision:  0.8836309523809524
# Recall:  0.8777777777777779
# F1:  0.8790931107004016
# TNR :  [0.97916667 0.97222222 0.97916667 0.92361111 0.99305556]
# TPR :  [0.80555556 0.86111111 0.91666667 0.86111111 0.94444444]
# FPR :  [0.02083333 0.02777778 0.02083333 0.07638889 0.00694444]
# FNR :  [0.19444444 0.13888889 0.08333333 0.13888889 0.05555556]
# ACC :  [0.94444444 0.95       0.96666667 0.91111111 0.98333333]
# PPV :  [0.90625    0.88571429 0.91666667 0.73809524 0.97142857]
# NPV :  [0.9527027  0.96551724 0.97916667 0.96376812 0.9862069 ]
# Fold:  3
# TRAIN: 720 TEST: 180
# 6/6 [==============================] - 0s 5ms/step
# Accuracy:  0.9166666666666666
# Precision:  0.9228684594538252
# Recall:  0.9166666666666666
# F1:  0.9165739299823807
# TNR :  [0.95833333 1.         0.96527778 0.97222222 1.        ]
# TPR :  [0.97222222 0.80555556 0.94444444 0.88888889 0.97222222]
# FPR :  [0.04166667 0.         0.03472222 0.02777778 0.        ]
# FNR :  [0.02777778 0.19444444 0.05555556 0.11111111 0.02777778]
# ACC :  [0.96111111 0.96111111 0.96111111 0.95555556 0.99444444]
# PPV :  [0.85365854 1.         0.87179487 0.88888889 1.        ]
# NPV :  [0.99280576 0.95364238 0.9858156  0.97222222 0.99310345]
# Fold:  4
# TRAIN: 720 TEST: 180
# 6/6 [==============================] - 0s 5ms/step
# Accuracy:  0.9111111111111111
# Precision:  0.9148157914011573
# Recall:  0.9111111111111111
# F1:  0.9106960011069599
# TNR :  [0.96527778 0.99305556 0.95833333 0.97222222 1.        ]
# TPR :  [0.88888889 0.80555556 0.97222222 0.88888889 1.        ]
# FPR :  [0.03472222 0.00694444 0.04166667 0.02777778 0.        ]
# FNR :  [0.11111111 0.19444444 0.02777778 0.11111111 0.        ]
# ACC :  [0.95       0.95555556 0.96111111 0.95555556 1.        ]
# PPV :  [0.86486486 0.96666667 0.85365854 0.88888889 1.        ]
# NPV :  [0.97202797 0.95333333 0.99280576 0.97222222 1.        ]
# Fold:  5
# TRAIN: 720 TEST: 180
# 6/6 [==============================] - 0s 5ms/step
# Accuracy:  0.9333333333333333
# Precision:  0.9355023923444976
# Recall:  0.9333333333333332
# F1:  0.9330694538932527
# TNR :  [0.96527778 0.99305556 0.97222222 0.98611111 1.        ]
# TPR :  [0.91666667 0.88888889 1.         0.86111111 1.        ]
# FPR :  [0.03472222 0.00694444 0.02777778 0.01388889 0.        ]
# FNR :  [0.08333333 0.11111111 0.         0.13888889 0.        ]
# ACC :  [0.95555556 0.97222222 0.97777778 0.96111111 1.        ]
# PPV :  [0.86842105 0.96969697 0.9        0.93939394 1.        ]
# NPV :  [0.97887324 0.97278912 1.         0.96598639 1.        ]

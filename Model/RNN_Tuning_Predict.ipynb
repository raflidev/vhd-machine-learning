# %%
import wave
import json
import librosa
import csv
import numpy as np
from pywt import wavedec
import pandas as pd
import tensorflow as tf
import os
import matplotlib.pyplot as plt

# %%
model_uri = '../modelh5/RNN_FT_KFold2.h5'
new_model = tf.keras.models.load_model(model_uri)
new_model.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_17 (SimpleRNN)   (None, 112, 64)           4224
#
#  dense_68 (Dense)            (None, 112, 32)           2080
#
#  flatten_17 (Flatten)        (None, 3584)              0
#
#  dense_69 (Dense)            (None, 64)                229440
#
#  dense_70 (Dense)            (None, 32)                2080
#
#  dense_71 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 237989 (929.64 KB)
# Trainable params: 237989 (929.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# model_uri = '../modelh5/model_rnn_tuning.h5'
# new_model = tf.keras.models.load_model(model_uri)
# new_model.summary()

# %%
# import wave
# import json
# header = 'filename'
# for i in range(1, 41):
#     header += f' mfcc{i}'
# for i in range(1, 13):
#   header += f' chroma{i}'
# for i in range(1, 61):
#   header += f' cqt{i}'
# header += ' label'
# header = header.split()
# file = open('testing.csv', 'w', newline='')
# with file:
#     writer = csv.writer(file)
#     writer.writerow(header)

# %%
# dataset_path = '../data/testing_10/'

# %%
# for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):
#         # ensure we're processing a genre sub-folder level
#         if dirpath is not dataset_path:
#             semantic_label = dirpath.split("/")[-1]
#             print("\nProcessing: {}".format(semantic_label))
#             for f in filenames:
#                 file_path = os.path.join(dirpath, f)
#                 to_append = f'{file_path}'
#                 # print(file_path)
#                 y, sr = librosa.load(file_path, mono=True, duration=3, sr=8000)
#                 coeffs = wavedec(y, 'db1', level=10)
#                 cA,cD10,cD9,cD8,cD7,cD6,cD5,cD4,cD3,cD2, cD1 = coeffs
#                 mfcc = librosa.feature.mfcc(y=cD1, sr=8000, n_mfcc=40, n_fft=2048, hop_length=512, n_mels=128)
#                 rms = librosa.feature.chroma_stft(y=cD1, sr=8000)
#                 cqt = np.abs(librosa.cqt(y=cD1, sr=sr, n_bins=60))
#                 combined_features = np.concatenate((mfcc, rms, cqt), axis=0)
#                 to_append = f'{file_path}'
#                 for e in combined_features:
#                     to_append += f' {np.mean(e.T, axis=0)}'
#                 to_append += f' {semantic_label}'
#                 file = open('testing.csv', 'a', newline='')
#                 with file:
#                     writer = csv.writer(file)
#                     writer.writerow(to_append.split())

# %%
data = pd.read_csv('./testing.csv')
data.head()
# Out:
#                                  filename       mfcc1      mfcc2      mfcc3  \
# 0  ../data/testing_10/MVP/New_MVP_135.wav -409.528564  87.384094  26.037184
# 1  ../data/testing_10/MVP/New_MVP_192.wav -337.002411  89.271080  14.186399
# 2  ../data/testing_10/MVP/New_MVP_179.wav -407.230621  70.930885 -13.684482
# 3  ../data/testing_10/MVP/New_MVP_165.wav -406.872314  84.138229  27.318718
# 4  ../data/testing_10/MVP/New_MVP_024.wav -479.023804  89.486000   8.549840
#
#        mfcc4      mfcc5      mfcc6      mfcc7      mfcc8      mfcc9  ...  \
# 0 -19.667170 -30.942360 -22.674948 -22.804028 -23.051409 -34.245644  ...
# 1   1.686405  -6.657608 -13.926779 -20.226974 -19.441204 -17.915880  ...
# 2 -34.369339 -21.889259 -15.245199 -11.328670  -9.168187 -16.146969  ...
# 3 -15.585702 -28.959631 -22.787647 -22.402174 -23.848078 -31.116653  ...
# 4  -0.640211  -7.605422 -15.150332 -16.487503 -13.620892 -10.753409  ...
#
#       cqt52     cqt53     cqt54     cqt55     cqt56     cqt57     cqt58  \
# 0  0.002009  0.001601  0.001465  0.001038  0.000982  0.000833  0.000616
# 1  0.002848  0.002626  0.003480  0.003186  0.003180  0.002202  0.001917
# 2  0.004742  0.004964  0.003947  0.003980  0.003126  0.003334  0.002728
# 3  0.003096  0.002835  0.002835  0.002727  0.002162  0.001437  0.000839
# 4  0.002732  0.001242  0.000721  0.001375  0.002052  0.002141  0.001541
#
#       cqt59     cqt60  label
# 0  0.000510  0.000491    MVP
# 1  0.002559  0.002665    MVP
# 2  0.002642  0.002220    MVP
# 3  0.000807  0.000667    MVP
# 4  0.000922  0.001057    MVP
#
# [5 rows x 114 columns]

# %%
X = data.drop(['label', 'filename'], axis=1)
y = data.iloc[:, -1]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
model = tf.keras.models.load_model(model_uri)
pred = model.predict(X)
hasil = []
class_labels = ['AS', 'MR', 'MS', 'MVP', 'N']
# class_labels = ['MVP', 'MS', 'N', 'MR', 'AS']
for i in pred:
    # hasil.append(np.argmax(i))
    print('===')
    print(i)
    cek = np.argmax(i)
    print(f'Actual class: {cek}')
    print(f'Predicted class: {class_labels[cek]}')
    print('===')
    hasil.append(class_labels[cek])
y_p = np.argmax(pred, axis=1)
# Out:
# 4/4 [==============================] - 0s 5ms/step
# ===
# [1.3187990e-04 3.1543768e-04 7.1274531e-05 9.9940097e-01 8.0431571e-05]
# Actual class: 3
# Predicted class: MVP
# ===
# ===
# [0.617845   0.01567533 0.12384739 0.23554018 0.00709218]
# Actual class: 0
# Predicted class: AS
# ===
# ===
# [0.02923929 0.237387   0.00247639 0.7290212  0.00187615]
# Actual class: 3
# Predicted class: MVP
# ===
# ===
# [5.1447395e-03 5.3435407e-04 7.0239953e-04 9.9176580e-01 1.8527086e-03]
# Actual class: 3
# Predicted class: MVP
# ===
# ===
# [0.00214958 0.0079648  0.02991615 0.420928   0.53904146]
# Actual class: 4
# Predicted class: N
# ===
# ===
# [1.17002855e-04 4.51417582e-05 7.41359472e-05 9.99583423e-01
#  1.80296192e-04]
# Actual class: 3
# Predicted class: MVP
# ===
# ===
# [1.0721394e-03 2.5866651e-05 1.3453880e-04 9.9832219e-01 4.4521425e-04]
# Actual class: 3
# Predicted class: MVP
# ===
# ===
# [7.5447309e-04 4.7707887e-04 3.2866807e-04 9.9804193e-01 3.9779421e-04]
# Actual class: 3
# Predicted class: MVP
# ===
# ===
# [0.00194765 0.00379    0.0427337  0.9026342  0.04889441]
# Actual class: 3
# Predicted class: MVP
# ===
# ===
# [4.5495780e-04 1.1082658e-04 5.5448787e-04 9.9854380e-01 3.3592939e-04]
# Actual class: 3
# Predicted class: MVP
# ===
# ===
# [5.7575619e-04 1.7333412e-04 6.1970029e-04 9.9749231e-01 1.1387847e-03]
# Actual class: 3
# Predicted class: MVP
# ===
# ===
# [6.2495215e-05 3.6694357e-05 2.8102819e-05 9.9982953e-01 4.3272328e-05]
# Actual class: 3
# Predicted class: MVP
# ===
# ===
# [6.2208954e-04 4.1479932e-05 2.2739959e-03 9.9661040e-01 4.5209361e-04]
# Actual class: 3
# Predicted class: MVP
# ===
# ===
# [0.0055092  0.00179271 0.24386473 0.4780799  0.27075335]
# Actual class: 3
# Predicted class: MVP
# ===
# ===
# [5.2156270e-04 1.7968920e-04 1.0225540e-04 9.9896955e-01 2.2682415e-04]
# Actual class: 3
# Predicted class: MVP
# ===
# ===
# [0.00342511 0.000991   0.00102767 0.9852629  0.00929334]
# Actual class: 3
# Predicted class: MVP
# ===
# ===
# [1.8750732e-03 7.5823948e-05 7.5249601e-04 9.9666435e-01 6.3222734e-04]
# Actual class: 3
# Predicted class: MVP
# ===
# ===
# [0.00979606 0.02639609 0.1336075  0.7694123  0.06078803]
# Actual class: 3
# Predicted class: MVP
# ===
# ===
# [1.1376453e-03 7.4439874e-04 1.9063542e-04 9.9763155e-01 2.9572463e-04]
# Actual class: 3
# Predicted class: MVP
# ===
# ===
# [1.5585751e-03 6.9838163e-05 5.2529748e-04 9.9683237e-01 1.0138506e-03]
# Actual class: 3
# Predicted class: MVP
# ===
# ===
# [1.4418346e-04 3.9768041e-04 9.9928522e-01 5.9635254e-06 1.6684520e-04]
# Actual class: 2
# Predicted class: MS
# ===
# ===
# [3.9288210e-05 7.7494071e-04 9.9895954e-01 7.2192095e-05 1.5391786e-04]
# Actual class: 2
# Predicted class: MS
# ===
# ===
# [1.29308915e-02 9.69914999e-03 9.75366414e-01 7.18245225e-04
#  1.28532748e-03]
# Actual class: 2
# Predicted class: MS
# ===
# ===
# [1.9849920e-01 4.9237203e-04 7.9262435e-01 3.5812049e-03 4.8029199e-03]
# Actual class: 2
# Predicted class: MS
# ===
# ===
# [2.3241085e-03 2.6171079e-03 9.9263912e-01 8.3659601e-04 1.5829904e-03]
# Actual class: 2
# Predicted class: MS
# ===
# ===
# [3.5224049e-03 3.1003375e-03 9.9291533e-01 1.2243024e-04 3.3964386e-04]
# Actual class: 2
# Predicted class: MS
# ===
# ===
# [3.8764325e-03 4.7461707e-02 9.4685924e-01 7.8937109e-04 1.0132797e-03]
# Actual class: 2
# Predicted class: MS
# ===
# ===
# [6.2731851e-05 7.3126517e-04 9.9898887e-01 7.9487210e-05 1.3767033e-04]
# Actual class: 2
# Predicted class: MS
# ===
# ===
# [1.5526907e-01 4.7232996e-04 8.3488756e-01 5.7183006e-03 3.6526339e-03]
# Actual class: 2
# Predicted class: MS
# ===
# ===
# [1.4298638e-04 2.1501139e-02 9.7207701e-01 4.9446709e-03 1.3341766e-03]
# Actual class: 2
# Predicted class: MS
# ===
# ===
# [0.00332728 0.00217729 0.8265368  0.15118228 0.01677641]
# Actual class: 2
# Predicted class: MS
# ===
# ===
# [2.8396153e-04 2.5469714e-04 9.9873525e-01 1.6339635e-04 5.6283048e-04]
# Actual class: 2
# Predicted class: MS
# ===
# ===
#
-04]
# Actual class: 1
# Predicted class: MR
# ===
# ===
# [1.9807277e-04 9.5665163e-01 5.4786769e-03 3.7000209e-02 6.7150383e-04]
# Actual class: 1
# Predicted class: MR
# ===
# ===
# [3.8058319e-04 9.9735773e-01 8.8856439e-04 1.2715643e-03 1.0145449e-04]
# Actual class: 1
# Predicted class: MR
# ===
# ===
# [5.6681718e-04 9.9401522e-01 2.2219955e-03 2.9324160e-03 2.6368850e-04]
# Actual class: 1
# Predicted class: MR
# ===
# ===
# [2.4886348e-04 9.9262756e-01 5.3654588e-04 5.4398244e-03 1.1471829e-03]
# Actual class: 1
# Predicted class: MR
# ===
# ===
# [0.5510327  0.15090346 0.28684613 0.00136627 0.00985137]
# Actual class: 0
# Predicted class: AS
# ===
# ===
# [3.3103616e-04 9.9485844e-01 2.8684454e-03 1.5579785e-03 3.8405738e-04]
# Actual class: 1
# Predicted class: MR
# ===
# ===
# [5.0033903e-04 9.9293625e-01 4.7272493e-04 5.7107420e-03 3.7999154e-04]
# Actual class: 1
# Predicted class: MR
# ===
# ===
# [7.4543685e-05 9.9043429e-01 2.1588134e-03 7.0204311e-03 3.1207348e-04]
# Actual class: 1
# Predicted class: MR
# ===
# ===
# [0.95722175 0.00483161 0.01022465 0.02319597 0.00452597]
# Actual class: 0
# Predicted class: AS
# ===
# ===
# [9.9636710e-01 9.9285657e-04 1.5358411e-03 6.6314742e-04 4.4105685e-04]
# Actual class: 0
# Predicted class: AS
# ===
# ===
# [0.9833017  0.00625376 0.00245569 0.00658911 0.00139974]
# Actual class: 0
# Predicted class: AS
# ===
# ===
# [9.9099660e-01 5.6623062e-04 2.9575366e-03 4.4877003e-03 9.9190185e-04]
# Actual class: 0
# Predicted class: AS
# ===
# ===
# [9.9694526e-01 1.4119814e-03 1.1116536e-03 1.9922035e-04 3.3190552e-04]
# Actual class: 0
# Predicted class: AS
# ===
# ===
# [9.9673432e-01 6.9334562e-04 1.5071518e-03 5.2036322e-04 5.4486445e-04]
# Actual class: 0
# Predicted class: AS
# ===
# ===
# [9.8984134e-01 9.8057755e-04 2.4438170e-03 5.8047655e-03 9.2938048e-04]
# Actual class: 0
# Predicted class: AS
# ===
# ===
# [0.9612473  0.00572266 0.01600672 0.00389064 0.0131327 ]
# Actual class: 0
# Predicted class: AS
# ===
# ===
# [9.9703854e-01 7.7701994e-04 1.0547665e-03 5.0851406e-04 6.2128523e-04]
# Actual class: 0
# Predicted class: AS
# ===
# ===
# [0.8421507  0.08169454 0.01202078 0.05820225 0.0059317 ]
# Actual class: 0
# Predicted class: AS
# ===
# ===
# [0.98214674 0.00244575 0.00539447 0.00579441 0.00421869]
# Actual class: 0
# Predicted class: AS
# ===
# ===
# [0.98641217 0.00354072 0.0031818  0.00547429 0.00139097]
# Actual class: 0
# Predicted class: AS
# ===
# ===
# [0.8704941  0.09605455 0.01322557 0.0172704  0.00295528]
# Actual class: 0
# Predicted class: AS
# ===
# ===
# [9.7955924e-01 2.8105741e-03 1.3649253e-02 3.1594574e-03 8.2138501e-04]
# Actual class: 0
# Predicted class: AS
# ===
# ===
# [0.981999   0.0050716  0.00267544 0.00898969 0.0012642 ]
# Actual class: 0
# Predicted class: AS
# ===
# ===
# [0.9911294  0.00139109 0.0046807  0.00162795 0.00117093]
# Actual class: 0
# Predicted class: AS
# ===
# ===
# [9.9696273e-01 1.5566241e-03 7.5313955e-04 3.4383353e-04 3.8364099e-04]
# Actual class: 0
# Predicted class: AS
# ===
# ===
# [9.9406612e-01 3.8999699e-03 1.3508381e-03 2.9984833e-04 3.8318630e-04]
# Actual class: 0
# Predicted class: AS
# ===
# ===
# [0.9584947  0.01157642 0.01267179 0.00733896 0.009918  ]
# Actual class: 0
# Predicted class: AS
# ===
# ===
# [0.956654   0.00602889 0.01278455 0.02158591 0.00294666]
# Actual class: 0
# Predicted class: AS
# ===

# %%
cm = confusion_matrix(y, hasil)
cm
# Out:
# array([[20,  0,  0,  0,  0],
#        [ 1, 19,  0,  0,  0],
#        [ 0,  1, 19,  0,  0],
#        [ 1,  0,  0, 18,  1],
#        [ 0,  0,  0,  0, 20]])

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['AS', 'MR', 'MS', 'MVP', 'N'])
disp.plot()
plt.show()

# %%
FP = cm.sum(axis=0) - np.diag(cm)  
FN = cm.sum(axis=1) - np.diag(cm)
TP = np.diag(cm)
TN = cm.sum() - (FP + FN + TP)

# Sensitivity, hit rate, recall, or true positive rate
TPR = TP/(TP+FN)
# Specificity or true negative rate
TNR = TN/(TN+FP) 
# Precision or positive predictive value
PPV = TP/(TP+FP)
# Negative predictive value
NPV = TN/(TN+FN)
# Fall out or false positive rate
FPR = FP/(FP+TN)
# False negative rate
FNR = FN/(TP+FN)
# False discovery rate
FDR = FP/(TP+FP)

# Overall accuracy
ACC = (TP+TN)/(TP+FP+FN+TN)

# %%
FP = cm.sum(axis=0) - np.diag(cm)  
FN = cm.sum(axis=1) - np.diag(cm)
TP = np.diag(cm)
TN = cm.sum() - (FP + FN + TP)

# Sensitivity, hit rate, recall, or true positive rate
TPR = TP/(TP+FN)
# Specificity or true negative rate
TNR = TN/(TN+FP) 
# Precision or positive predictive value
PPV = TP/(TP+FP)
# Negative predictive value
NPV = TN/(TN+FN)
# Fall out or false positive rate
FPR = FP/(FP+TN)
# False negative rate
FNR = FN/(TP+FN)
# False discovery rate
FDR = FP/(TP+FP)

# Overall accuracy
ACC = (TP+TN)/(TP+FP+FN+TN)

# %%
print("Sensitivity :" , TPR, 'mean: ', np.mean(TPR))
print("Specificity :" , TNR, 'mean: ', np.mean(TNR))
print("Precision :" , PPV, 'mean: ', np.mean(PPV))
print("Accuracy :" , ACC, 'mean: ', np.mean(ACC))
print("FPR :" , FPR, 'mean: ', np.mean(FPR))
print("FNR :" , FNR, 'mean: ', np.mean(FNR))
print("NPV :" , NPV, 'mean: ', np.mean(NPV))
print("FDR :" , FDR, 'mean: ', np.mean(FDR))
print("f1_score:", 2 * (PPV * TPR) / (PPV + TPR), 'mean: ', np.mean(2 * (PPV * TPR) / (PPV + TPR)))
# Out:
# Sensitivity : [1.   0.95 0.95 0.9  1.  ] mean:  0.96
# Specificity : [0.975  0.9875 1.     1.     0.9875] mean:  0.99
# Precision : [0.90909091 0.95       1.         1.         0.95238095] mean:  0.9622943722943722
# Accuracy : [0.98 0.98 0.99 0.98 0.99] mean:  0.984
# FPR : [0.025  0.0125 0.     0.     0.0125] mean:  0.01
# FNR : [0.   0.05 0.05 0.1  0.  ] mean:  0.04
# NPV : [1.         0.9875     0.98765432 0.97560976 1.        ] mean:  0.990152815417043
# FDR : [0.09090909 0.05       0.         0.         0.04761905] mean:  0.03770562770562771
# f1_score: [0.95238095 0.95       0.97435897 0.94736842 0.97560976] mean:  0.9599436207780239
